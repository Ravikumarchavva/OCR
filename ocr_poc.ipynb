# %% [markdown]
# # Table of contents
# 1. [Introduction](#introduction)
# 2. [Invoice sample](#invoice-sample)
# 3. [gemini](#gemini)
# 4. [extract-json](#extract-json)
# 5. [Using all files](#using-all-files)
# 6. [Saving the output](#saving-the-output)
# 7. [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction
# This notebook demonstrates how to extract details from a PDF invoice using the `gemini` and `save-as-json` nodes.

# %% [markdown]
# ## Invoice sample
# The sample invoice used in this notebook is a PDF file that contains the following details:

# %%
from pdf2image import convert_from_path  # pdf not getting displayed in jupyter notebook so using pdf2image to convert pdf to image
from IPython.display import display, HTML
from pathlib import Path

# Project root directory
project_root = Path().resolve()

# Path to PDF file
pdf_path = project_root / 'invoices' / 'invoice_1.pdf'

# Convert pdf to an image
images = convert_from_path(pdf_path)
display(images[0])
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1654x2339>

# %% [markdown]
# ## gemini
# The `gemini` model is used to extract the text from the PDF invoice.

# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv
load_dotenv()

GCP_KEY = os.getenv("GCP_KEY")

genai.configure(api_key=GCP_KEY)
model = genai.GenerativeModel("gemini-1.5-flash")

# %% [markdown]
# ## extract-json
# The `extract-json` script is used to extract the required details from the file and return as json.

# %%
import base64
import json
import re
from json2html import json2html

# encode and decode the pdf file using base64 to make sure the file is in the correct format
with open(pdf_path, "rb") as pdf_file:
    pdf_data = pdf_file.read()
transformed_pdf = base64.standard_b64encode(pdf_data).decode("utf-8")

# Prompt for the model
prompt = "Extract invoice details from the file . and write as json"

# Generate content from the model
response = model.generate_content(
    [{'mime_type': 'application/pdf', 'data': transformed_pdf},
    prompt]
)
response_text = response.text

# Extract JSON data from model response
match = re.search(r"\{.*\}", response_text, re.DOTALL)
if match:
    invoice_data = json.loads(match.group(0))
else:
    raise ValueError("No valid JSON found in response")

# Print extracted JSON as HTML table
html_table = json2html.convert(json=invoice_data)
display(HTML(html_table))
# Out:
# <table border="1"><tr><th>invoice_no</th><td>49565075</td></tr><tr><th>date_of_issue</th><td>10/28/2019</td></tr><tr><th>seller</th><td><table border="1"><tr><th>name</th><td>Kane-Morgan</td></tr><tr><th>address</th><td>968 Carr Mission Apt. 320
# Bernardville, VA 28211</td></tr><tr><th>tax_id</th><td>964-95-3813</td></tr><tr><th>iban</th><td>GB73WCIJ55232646970614</td></tr></table></td></tr><tr><th>client</th><td><table border="1"><tr><th>name</th><td>Garcia Inc</td></tr><tr><th>address</th><td>445 Haas Viaduct Suite 454
# Michaelhaven, LA 32852</td></tr><tr><th>tax_id</th><td>909-75-5482</td></tr></table></td></tr><tr><th>items</th><td><table border="1"><thead><tr><th>no</th><th>description</th><th>qty</th><th>um</th><th>net_price</th><th>net_worth</th><th>vat_percentage</th><th>gross_worth</th></tr></thead><tbody><tr><td>1</td><td>Anthropologie Gold Elegant Swan Decorative Metal Bottle Stopper Wine Saver</td><td>3.0</td><td>each</td><td>19.98</td><td>59.94</td><td>10</td><td>65.93</td></tr><tr><td>2</td><td>Lolita Happy Retirement Wine Glass 15 Ounce GLS11-5534H</td><td>1.0</td><td>each</td><td>8.0</td><td>8.0</td><td>10</td><td>8.8</td></tr><tr><td>3</td><td>Lolita &quot;Congratulations&quot; Hand Painted and Decorated Wine Glass NIB</td><td>1.0</td><td>each</td><td>20.0</td><td>20.0</td><td>10</td><td>22.0</td></tr></tbody></table></td></tr><tr><th>summary</th><td><table border="1"><tr><th>vat_percentage</th><td>10</td></tr><tr><th>net_worth</th><td>87.94</td></tr><tr><th>vat</th><td>8.79</td></tr><tr><th>gross_worth</th><td>96.73</td></tr></table></td></tr></table>

# %% [markdown]
# ## Using all files
# The `gemini` and `extract-json` nodes are now used to extract the details from all the PDF invoice. `Using 5 files to adhere to gemini's limits`

# %%
from tqdm.auto import tqdm 

class Invoice:
    def __init__(self, data):
        self.data = data
    
    def __getitem__(self, key):
        return self.data[key]
    
class InvoiceExtractor:

    def __init__(self, model):
        self.model = model

    @staticmethod
    def transform_pdf(file_path):
        with open(file_path, "rb") as pdf_file:
            pdf_data = pdf_file.read()
        return base64.standard_b64encode(pdf_data).decode("utf-8")
    
    @staticmethod
    def extract_json(response_text):
        """Extracts JSON data from model response."""
        match = re.search(r"\{.*\}", response_text, re.DOTALL)
        if match:
            return json.loads(match.group(0))
        raise ValueError("No valid JSON found in response")

    def extract(self, pdf_path):
        encoded_pdf = self.transform_pdf(pdf_path)
        prompt = "Extract invoice details from the file . and write as json"

        response = self.model.generate_content(
            [{'mime_type': 'application/pdf', 'data': encoded_pdf},
            prompt]
        )

        response_text = response.text
        invoice_data = self.extract_json(response_text)

        return Invoice(invoice_data)
    
    def extract_all(self, pdf_dir, limit=None):
        invoices = []
        pdfs = list(pdf_dir.glob("*.pdf"))
        len_pdfs = len(pdfs)
        if limit:
            if limit > len_pdfs:
                limit = len_pdfs
            pdfs = pdfs[:limit]      
              
        for pdf_path in tqdm(pdfs):
            invoice = self.extract(pdf_path)
            invoices.append(invoice)
        return invoices
    
    @staticmethod
    def display(invoice):
        html_table = json2html.convert(json=invoice.data)
        display(HTML(html_table))

    def display_all(self, invoices):
        for invoice in invoices:
            self.display(invoice)

    @staticmethod
    def save(invoice, output_dir):
        output_dir.mkdir(parents=True, exist_ok=True)
        output_path = output_dir / f"{invoice['invoice_no']}.json"
        with open(output_path, "w") as output_file:
            json.dump(invoice.data, output_file, indent=2)

    def save_all(self, invoices, output_dir):
        for invoice in invoices:
            self.save(invoice, output_dir)
    
extractor = InvoiceExtractor(model)
invoices = extractor.extract_all(project_root / 'invoices', limit=5)
extractor.display_all(invoices)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# <table border="1"><tr><th>invoice_no</th><td>40378170</td></tr><tr><th>date_of_issue</th><td>10/15/2012</td></tr><tr><th>seller</th><td><table border="1"><tr><th>name</th><td>Patel, Thompson and Montgomery</td></tr><tr><th>address</th><td>356 Kyle Vista
# New James, MA 46228</td></tr><tr><th>tax_id</th><td>958-74-3511</td></tr><tr><th>iban</th><td>GB77WRBQ31965128414006</td></tr></table></td></tr><tr><th>client</th><td><table border="1"><tr><th>name</th><td>Jackson, Odonnell and Jackson</td></tr><tr><th>address</th><td>267 John Track Suite 841
# Jenniferville, PA 98601</td></tr><tr><th>tax_id</th><td>998-87-7723</td></tr></table></td></tr><tr><th>items</th><td><table border="1"><thead><tr><th>no</th><th>description</th><th>qty</th><th>um</th><th>net_price</th><th>net_worth</th><th>vat_percentage</th><th>gross_worth</th></tr></thead><tbody><tr><td>1</td><td>Leed&#x27;s Wine Companion Bottle Corkscrew Opener Gift Box Set with Foil Cutter</td><td>1.0</td><td>each</td><td>7.5</td><td>7.5</td><td>10</td><td>8.25</td></tr></tbody></table></td></tr><tr><th>summary</th><td><table border="1"><tr><th>vat_percentage</th><td>10</td></tr><tr><th>net_worth</th><td>7.5</td></tr><tr><th>vat</th><td>0.75</td></tr><tr><th>gross_worth</th><td>8.25</td></tr><tr><th>total</th><td><table border="1"><tr><th>net_worth</th><td>7.5</td></tr><tr><th>vat</th><td>0.75</td></tr><tr><th>gross_worth</th><td>8.25</td></tr></table></td></tr></table></td></tr></table>
# <table border="1"><tr><th>invoice_no</th><td>61356291</td></tr><tr><th>date_of_issue</th><td>09/06/2012</td></tr><tr><th>seller</th><td><table border="1"><tr><th>name</th><td>Chapman, Kim and Green</td></tr><tr><th>address</th><td>64731 James Branch
# Smithmouth, NC 26872</td></tr><tr><th>tax_id</th><td>949-84-9105</td></tr><tr><th>iban</th><td>GB50ACIE59715038217063</td></tr></table></td></tr><tr><th>client</th><td><table border="1"><tr><th>name</th><td>Rodriguez-Stevens</td></tr><tr><th>address</th><td>2280 Angela Plain
# Hortonshire, MS 93248</td></tr><tr><th>tax_id</th><td>939-98-8477</td></tr></table></td></tr><tr><th>items</th><td><table border="1"><thead><tr><th>no</th><th>description</th><th>qty</th><th>um</th><th>net_price</th><th>net_worth</th><th>vat</th><th>gross_worth</th></tr></thead><tbody><tr><td>1</td><td>Wine Glasses Goblets Pair Clear Glass</td><td>5.0</td><td>each</td><td>12.0</td><td>60.0</td><td>10</td><td>66.0</td></tr><tr><td>2</td><td>With Hooks Stemware Storage Multiple Uses Iron Wine Rack Hanging Glass</td><td>1.0</td><td>each</td><td>28.06</td><td>112.32</td><td>10</td><td>123.55</td></tr><tr><td>3</td><td>Replacement Corkscrew Parts Spiral Worm Wine Opener Bottle Houdini</td><td>1.0</td><td>each</td><td>7.5</td><td>7.5</td><td>10</td><td>8.25</td></tr><tr><td>4</td><td>HOME ESSENTIALS GRADIENT STEMLESS WINE GLASSES SET OF 4 20 FL OZ (591 ml) NEW</td><td>1.0</td><td>each</td><td>12.99</td><td>12.99</td><td>10</td><td>14.29</td></tr></tbody></table></td></tr><tr><th>summary</th><td><table border="1"><tr><th>vat</th><td>10</td></tr><tr><th>net_worth</th><td>192.81</td></tr><tr><th>vat_amount</th><td>19.28</td></tr><tr><th>gross_worth</th><td>212.09</td></tr></table></td></tr></table>
# <table border="1"><tr><th>invoice_no</th><td>49565075</td></tr><tr><th>date_of_issue</th><td>10/28/2019</td></tr><tr><th>seller</th><td><table border="1"><tr><th>name</th><td>Kane-Morgan</td></tr><tr><th>address</th><td>968 Carr Mission Apt. 320
# Bernardville, VA 28211</td></tr><tr><th>tax_id</th><td>964-95-3813</td></tr><tr><th>iban</th><td>GB73WCIJ55232646970614</td></tr></table></td></tr><tr><th>client</th><td><table border="1"><tr><th>name</th><td>Garcia Inc</td></tr><tr><th>address</th><td>445 Haas Viaduct Suite 454
# Michaelhaven, LA 32852</td></tr><tr><th>tax_id</th><td>909-75-5482</td></tr></table></td></tr><tr><th>items</th><td><table border="1"><thead><tr><th>no</th><th>description</th><th>qty</th><th>um</th><th>net_price</th><th>net_worth</th><th>vat_percentage</th><th>gross_worth</th></tr></thead><tbody><tr><td>1</td><td>Anthropologie Gold Elegant Swan Decorative Metal Bottle Stopper Wine Saver</td><td>3.0</td><td>each</td><td>19.98</td><td>59.94</td><td>10</td><td>65.93</td></tr><tr><td>2</td><td>Lolita Happy Retirement Wine Glass 15 Ounce GLS11-5534H</td><td>1.0</td><td>each</td><td>8.0</td><td>8.0</td><td>10</td><td>8.8</td></tr><tr><td>3</td><td>Lolita &quot;Congratulations&quot; Hand Painted and Decorated Wine Glass NIB</td><td>1.0</td><td>each</td><td>20.0</td><td>20.0</td><td>10</td><td>22.0</td></tr></tbody></table></td></tr><tr><th>summary</th><td><table border="1"><tr><th>vat_percentage</th><td>10</td></tr><tr><th>net_worth</th><td>87.94</td></tr><tr><th>vat</th><td>8.79</td></tr><tr><th>gross_worth</th><td>96.73</td></tr></table></td></tr></table>
# <table border="1"><tr><th>invoice_no</th><td>95611677</td></tr><tr><th>date_of_issue</th><td>07/19/2016</td></tr><tr><th>seller</th><td><table border="1"><tr><th>name</th><td>Franco Group</td></tr><tr><th>address</th><td>796 Arnold Cove Apt. 091
# Reginaport, AZ 06940</td></tr><tr><th>tax_id</th><td>973-97-5084</td></tr><tr><th>iban</th><td>GB95MPFV88552069556163</td></tr></table></td></tr><tr><th>client</th><td><table border="1"><tr><th>name</th><td>Johnson Group</td></tr><tr><th>address</th><td>0693 Robin Mountain Apt. 180
# Lake Christina, MI 87634</td></tr><tr><th>tax_id</th><td>952-81-0165</td></tr></table></td></tr><tr><th>items</th><td><table border="1"><thead><tr><th>no</th><th>description</th><th>qty</th><th>um</th><th>net_price</th><th>net_worth</th><th>vat</th><th>gross_worth</th></tr></thead><tbody><tr><td>1</td><td>Round Indian Braided Jute Carpet | Hand Woven Brown Round Shape Living Room Rug</td><td>5.0</td><td>each</td><td>49.99</td><td>249.95</td><td>10</td><td>274.95</td></tr><tr><td>2</td><td>Cartoon Rabbit Printed Round Carpet Area Rug Children Play Tent Floor Mat Rug</td><td>4.0</td><td>each</td><td>177.08</td><td>708.32</td><td>10</td><td>779.15</td></tr></tbody></table></td></tr><tr><th>summary</th><td><table border="1"><tr><th>vat</th><td>10</td></tr><tr><th>net_worth</th><td>958.27</td></tr><tr><th>vat_amount</th><td>95.83</td></tr><tr><th>gross_worth</th><td>1054.1</td></tr></table></td></tr></table>
# <table border="1"><tr><th>invoice_no</th><td>26020078</td></tr><tr><th>date_of_issue</th><td>11/19/2019</td></tr><tr><th>seller</th><td><table border="1"><tr><th>name</th><td>Johnson, Coleman and Mccarthy</td></tr><tr><th>address</th><td>Unit 1928 Box 1473
# DPO AA 74927</td></tr><tr><th>tax_id</th><td>944-91-8763</td></tr><tr><th>iban</th><td>GB93YUAY48784201603098</td></tr></table></td></tr><tr><th>client</th><td><table border="1"><tr><th>name</th><td>Ochoa, Crane and Johnston</td></tr><tr><th>address</th><td>537 Johnson Rapid Suite 176
# Morrowmouth, AK 77182</td></tr><tr><th>tax_id</th><td>942-86-9388</td></tr></table></td></tr><tr><th>items</th><td><table border="1"><thead><tr><th>no</th><th>description</th><th>qty</th><th>um</th><th>net_price</th><th>net_worth</th><th>vat</th><th>gross_worth</th></tr></thead><tbody><tr><td>1</td><td>The Children&#x27;s Place Brown Dress Boy Lace Up Shoes Size 12</td><td>1.0</td><td>each</td><td>8.0</td><td>8.0</td><td>10</td><td>8.8</td></tr><tr><td>2</td><td>All Mattel Disney Pixar Model Cars McQueen 1:55 Diecast Lot Choose Loose Kid Toy</td><td>5.0</td><td>each</td><td>12.99</td><td>64.95</td><td>10</td><td>71.45</td></tr><tr><td>3</td><td>KushyShoo Children Kid Rain Boot Shoes Rubber, Monkey, Size Youth 1</td><td>1.0</td><td>each</td><td>22.99</td><td>22.99</td><td>10</td><td>25.29</td></tr><tr><td>4</td><td>Western Chief Kids&#x27; Boys Classic Rain Boots w/ Pull Handles Navy Blue Size 12</td><td>1.0</td><td>each</td><td>9.99</td><td>9.99</td><td>10</td><td>10.99</td></tr></tbody></table></td></tr><tr><th>summary</th><td><table border="1"><tr><th>vat</th><td>10</td></tr><tr><th>net_worth</th><td>105.93</td></tr><tr><th>vat_amount</th><td>10.59</td></tr><tr><th>gross_worth</th><td>116.52</td></tr></table></td></tr></table>

# %% [markdown]
# ## Saving the output
# The extracted details are saved as a json file.

# %%
extractor.save_all(invoices, project_root / 'output_invoices')

# %% [markdown]
# ## Conclusion
# This notebook demonstrates how to extract details from a PDF invoice using the `gemini` and `save-as-json` nodes.

# %%
invoices[0].data
# Out:
# {'invoice_no': '40378170',
#  'date_of_issue': '10/15/2012',
#  'seller': {'name': 'Patel, Thompson and Montgomery',
#   'address': '356 Kyle Vista\nNew James, MA 46228',
#   'tax_id': '958-74-3511',
#   'iban': 'GB77WRBQ31965128414006'},
#  'client': {'name': 'Jackson, Odonnell and Jackson',
#   'address': '267 John Track Suite 841\nJenniferville, PA 98601',
#   'tax_id': '998-87-7723'},
#  'items': [{'no': 1,
#    'description': "Leed's Wine Companion Bottle Corkscrew Opener Gift Box Set with Foil Cutter",
#    'qty': 1.0,
#    'um': 'each',
#    'net_price': 7.5,
#    'net_worth': 7.5,
#    'vat_percentage': 10,
#    'gross_worth': 8.25}],
#  'summary': {'vat_percentage': 10,
#   'net_worth': 7.5,
#   'vat': 0.75,
#   'gross_worth': 8.25,
#   'total': {'net_worth': 7.5, 'vat': 0.75, 'gross_worth': 8.25}}}

# %% [markdown]
# ## 2nd pdf

# %%
invoices[1].data
# Out:
# {'invoice_no': '61356291',
#  'date_of_issue': '09/06/2012',
#  'seller': {'name': 'Chapman, Kim and Green',
#   'address': '64731 James Branch\nSmithmouth, NC 26872',
#   'tax_id': '949-84-9105',
#   'iban': 'GB50ACIE59715038217063'},
#  'client': {'name': 'Rodriguez-Stevens',
#   'address': '2280 Angela Plain\nHortonshire, MS 93248',
#   'tax_id': '939-98-8477'},
#  'items': [{'no': 1,
#    'description': 'Wine Glasses Goblets Pair Clear Glass',
#    'qty': 5.0,
#    'um': 'each',
#    'net_price': 12.0,
#    'net_worth': 60.0,
#    'vat': 10,
#    'gross_worth': 66.0},
#   {'no': 2,
#    'description': 'With Hooks Stemware Storage Multiple Uses Iron Wine Rack Hanging Glass',
#    'qty': 1.0,
#    'um': 'each',
#    'net_price': 28.06,
#    'net_worth': 112.32,
#    'vat': 10,
#    'gross_worth': 123.55},
#   {'no': 3,
#    'description': 'Replacement Corkscrew Parts Spiral Worm Wine Opener Bottle Houdini',
#    'qty': 1.0,
#    'um': 'each',
#    'net_price': 7.5,
#    'net_worth': 7.5,
#    'vat': 10,
#    'gross_worth': 8.25},
#   {'no': 4,
#    'description': 'HOME ESSENTIALS GRADIENT STEMLESS WINE GLASSES SET OF 4 20 FL OZ (591 ml) NEW',
#    'qty': 1.0,
#    'um': 'each',
#    'net_price': 12.99,
#    'net_worth': 12.99,
#    'vat': 10,
#    'gross_worth': 14.29}],
#  'summary': {'vat': 10,
#   'net_worth': 192.81,
#   'vat_amount': 19.28,
#   'gross_worth': 212.09}}
